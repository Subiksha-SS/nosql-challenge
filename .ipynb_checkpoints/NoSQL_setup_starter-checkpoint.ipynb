# %% [markdown]
# # Eat Safe, Love

# %% [markdown]
# ## Part 1: Database and Jupyter Notebook Set Up

# %% [markdown]
# Import the data provided in the `establishments.json` file from your Terminal. Name the database `uk_food` and the collection `establishments`.
#
# Within this markdown cell, copy the line of text you used to import the data from your Terminal. This way, future analysts will be able to repeat your process.
#
# e.g.: Import the dataset with `mongoimport --type json -d uk_food -c establishments --drop --jsonArray establishments.json`

# %%
# Import dependencies
from pymongo import MongoClient
from pprint import pprint

# %%
# Create an instance of MongoClient
mongo = MongoClient(port=27017)

# %%
# confirm that our new database was created
if 'uk_food' in mongo.list_database_names():
    print ("New database uk_food was created")
else:
    print ("New database uk_food was not created")
# Out:
# New database uk_food was created

# %%
# assign the uk_food database to a variable name
db = mongo['uk_food']

# %%
# review the collections in our new database
print(db.list_collection_names())
# Out:
# ['establishments']

# %%
# review the collections in our new database
print(db.list_collection_names())
# Out:
# ['establishments']

# %%
# review a document in the establishments collection
db.establishments.find_one()
# Out:
# {'_id': ObjectId('64f88f6aa99d5d899e13a42f'),
#  'FHRSID': 289353,
#  'ChangesByServerID': 0,
#  'LocalAuthorityBusinessID': 'PI/000002468',
#  'BusinessName': 'St Marys COE (aided) Primary School',
#  'BusinessType': 'School/college/university',
#  'BusinessTypeID': 7845,
#  'AddressLine1': 'St Marys Church Of England Primary School',
#  'AddressLine2': 'Warren Road',
#  'AddressLine3': 'Folkestone',
#  'AddressLine4': 'Kent',
#  'PostCode': 'CT19 6QH',
#  'Phone': '',
#  'RatingValue': '5',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingDate': '2016-09-13T00:00:00',
#  'LocalAuthorityCode': '188',
#  'LocalAuthorityName': 'Folkestone and Hythe',
#  'LocalAuthorityWebSite': 'http://www.folkestone-hythe.gov.uk',
#  'LocalAuthorityEmailAddress': 'foodteam@folkestone-hythe.gov.uk',
#  'scores': {'Hygiene': 0, 'Structural': 0, 'ConfidenceInManagement': 0},
#  'SchemeType': 'FHRS',
#  'geocode': {'longitude': '1.194762', 'latitude': '51.085797'},
#  'RightToReply': '',
#  'Distance': 4591.871474174837,
#  'NewRatingPending': False,
#  'meta': {'dataSource': None,
#   'extractDate': '0001-01-01T00:00:00',
#   'itemCount': 0,
#   'returncode': None,
#   'totalCount': 0,
#   'totalPages': 0,
#   'pageSize': 0,
#   'pageNumber': 0},
#  'links': [{'rel': 'self',
#    'href': 'https://api.ratings.food.gov.uk/establishments/289353'}]}

# %%
# assign the collection to a variable
establishments = db['establishments']

# %% [markdown]
# ## Part 2: Update the Database

# %% [markdown]
# 1. An exciting new halal restaurant just opened in Greenwich, but hasn't been rated yet. The magazine has asked you to include it in your analysis. Add the following restaurant "Penang Flavours" to the database.

# %%
# Create a dictionary for the new restaurant data
new_restaurant = {"BusinessName":"Penang Flavours",
    "BusinessType":"Restaurant/Cafe/Canteen",
    "BusinessTypeID":"",
    "AddressLine1":"Penang Flavours",
    "AddressLine2":"146A Plumstead Rd",
    "AddressLine3":"London",
    "AddressLine4":"",
    "PostCode":"SE18 7DY",
    "Phone":"",
    "LocalAuthorityCode":"511",
    "LocalAuthorityName":"Greenwich",
    "LocalAuthorityWebSite":"http://www.royalgreenwich.gov.uk",
    "LocalAuthorityEmailAddress":"health@royalgreenwich.gov.uk",
    "scores":{
        "Hygiene":"",
        "Structural":"",
        "ConfidenceInManagement":""
    },
    "SchemeType":"FHRS",
    "geocode":{
        "longitude":"0.08384000",
        "latitude":"51.49014200"
    },
    "RightToReply":"",
    "Distance":4623.9723280747176,
    "NewRatingPending":True}

# %%
# Insert the new restaurant into the collection
establishments.insert_one(new_restaurant)

# %%
# Check that the new restaurant was inserted
query = {"BusinessName":"Penang Flavours"}
results = establishments.find(query)

for r in results:
    print(r)
# Out:
# {'_id': ObjectId('64f90c730d89e46200648faf'), 'BusinessName': 'Penang Flavours', 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1, 'AddressLine1': 'Penang Flavours', 'AddressLine2': '146A Plumstead Rd', 'AddressLine3': 'London', 'AddressLine4': '', 'PostCode': 'SE18 7DY', 'Phone': '', 'LocalAuthorityCode': '511', 'LocalAuthorityName': 'Greenwich', 'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk', 'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk', 'scores': {'Hygiene': '', 'Structural': '', 'ConfidenceInManagement': ''}, 'SchemeType': 'FHRS', 'geocode': {'longitude': '0.08384000', 'latitude': '51.49014200'}, 'RightToReply': '', 'Distance': 4623.972328074718, 'NewRatingPending': True}

# %% [markdown]
# 2. Find the BusinessTypeID for "Restaurant/Cafe/Canteen" and return only the `BusinessTypeID` and `BusinessType` fields.

# %%
# Find the BusinessTypeID for "Restaurant/Cafe/Canteen" and return only the BusinessTypeID and BusinessType fields
query = {"BusinessType": "Restaurant/Cafe/Canteen"}
fields = {'BusinessTypeID':1, 'BusinessType':1}
results_business_type = establishments.find(query, fields)

for b in results_business_type:
    print(b)
# Out:
# {'_id': ObjectId('64f88f6aa99d5d899e13a431'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13a43d'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13a441'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13a442'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13a44b'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13a452'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13a458'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13a45c'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13a45f'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13a460'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13a46f'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13a471'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13a472'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13a479'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13a47d'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13a483'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13a487'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13a488'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13a48d'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13a48f'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13a490'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13a491'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13a492'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13a494'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13a499'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13a49c'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13a49d'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13a49e'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13a4a4'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13a4a5'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13a4a8'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13a4a9'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13a4ac'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13a4ad'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13a4b8'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13a4ba'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13a4bd'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13a4be'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13a4c2'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13a4c3'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13a4c4'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13a4ca'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13a4cc'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13a4cd'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13a4ce'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13a4d0'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13a4d7'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13a4d9'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13a4da'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13a4dc'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13a4e1'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13a4e2'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13a4e7'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13a4e9'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13a4ec'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13a4ed'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13a4f2'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13a4f4'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13a4f5'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13a4fb'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13a4fe'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13a503'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13a507'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13a50a'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13a50c'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13a50d'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13a512'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13a516'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13a517'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13a518'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13a51a'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13a51e'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13a51f'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13a521'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13a522'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13a524'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13a530'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13a534'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13a535'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13a539'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13a53a'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13a53b'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13a540'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13a541'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13a546'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13a547'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13a549'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13a54e'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13a552'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13a553'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13a555'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13a559'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13a564'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13a57d'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13a581'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13a587'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13a588'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13a596'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13a5a5'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13a5b0'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13a5b1'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13a5b3'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13a5b5'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13a5c1'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13a5c3'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13a5c4'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13a5c5'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13a5c7'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13a5ca'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13a5cc'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13a5cd'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13a5ce'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13a5cf'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13a5d0'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13a5d6'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13a5e1'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13a5e5'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13a5e6'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13a5e7'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13a5e8'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13a5e9'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13a5ea'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13a5eb'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13a5ec'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13a5f1'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13a5f2'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13a5f4'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13a5fe'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13a5ff'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13a601'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13a603'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13a604'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13a605'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13a607'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13a60b'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13a60d'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13a60e'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13a61a'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13a61b'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13a61d'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13a61e'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13a620'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13a622'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13a629'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13a630'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13a631'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13a637'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13a638'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13a63c'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13a63f'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13a640'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13a643'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13a648'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13a64f'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13a655'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13a65b'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13a65e'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13a661'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13a665'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13a666'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13a66e'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13a671'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13a676'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13a678'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13a679'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13a67e'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13a681'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13a684'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13a689'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13a68a'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13a68d'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13a692'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13a698'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13a699'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13a69a'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13a69d'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13a6a2'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13a6a3'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13a6a4'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13a6a5'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13a6a6'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13a6a7'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13a6a9'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13a6aa'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13a6ac'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13a6ad'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13a6b0'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13a6b1'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13a6b2'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13a6b3'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13a6b5'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13a6b7'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13a6b9'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13a6ba'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13a6bb'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13a6bd'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13a6be'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13a6c0'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13a6c3'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13a6c5'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13a6cd'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13a6ce'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13a6d0'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13a6d1'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13a6d2'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13a6d3'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13a6d4'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13a6dd'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13a6de'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13a6df'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13a6e2'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13a6e4'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13a6e6'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13a6eb'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13a6ed'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13a6f5'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13a6f6'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13a706'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13a709'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13a710'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13a71a'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13a71e'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13a723'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13a72a'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13a72d'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13a736'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13a738'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13a73a'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13a73b'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13a73c'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13a740'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13a743'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13a748'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13a749'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13a757'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13a758'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13a75e'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13a766'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13a769'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13a771'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13a772'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13a77a'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13a790'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13a79c'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13a7a2'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13a7a3'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13a7af'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13a7c5'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13a7c9'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13a7ca'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13a7cb'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13a7cc'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13a7d9'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13a7da'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13a7dc'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13a7e3'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13a7e5'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13a810'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13a811'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13a813'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13a818'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13a81d'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13a81e'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13a824'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13a826'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13a82b'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13a832'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13a833'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13a838'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13a84b'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13a84c'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13a851'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13a852'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13a855'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13a856'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13a857'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13a862'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13a865'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13a866'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13a870'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13a878'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13a884'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13a88c'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13a88f'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13a891'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13a894'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13a897'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13a89e'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13a8a4'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13a8a8'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13a8a9'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13a8ac'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13a8b1'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13a8b7'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13a8bf'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13a8ce'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13a8d3'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13a8d7'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13a8dc'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13a8e3'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13a8e6'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13a8eb'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13a8f2'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13a8f3'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13a900'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13a903'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13a904'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13a906'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13a908'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13a90e'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13a915'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13a918'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13a919'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13a91a'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13a91b'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13a91d'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13a91f'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13a922'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13a924'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13a925'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13a926'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13a92e'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13a92f'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13a930'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13a932'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13a937'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13a938'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13a93d'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13a93e'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13a93f'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13a940'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13a944'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13a94a'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13a94d'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13a94e'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13a950'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13a951'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13a952'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13a954'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13a955'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13a958'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13a95a'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13a95b'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13a95d'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13a95e'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13a95f'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13a964'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13a968'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13a969'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13a96a'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13a96e'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13a973'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13a975'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13a977'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13a988'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13a98d'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13a991'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13a996'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13a997'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13a9a6'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13a9a8'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13a9aa'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13a9ab'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13a9ac'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13a9ae'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13a9af'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13a9bb'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13a9c0'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13a9c1'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13a9c3'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13a9c5'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13a9ca'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13a9d1'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13a9d2'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13a9d7'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13a9d9'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13a9da'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13a9dd'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13a9e0'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13a9e1'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13a9e7'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13a9e8'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13a9e9'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13a9ec'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13a9fb'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13aa02'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13aa09'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13aa13'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13aa15'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13aa18'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13aa1d'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13aa1f'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13aa22'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13aa24'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13aa27'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13aa29'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13aa2a'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13aa2b'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13aa2c'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13aa35'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13aa3d'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13aa4e'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13aa58'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13aa5d'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13aa6b'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13aa6f'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13aa70'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13aa71'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13aa81'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13aa96'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13aa97'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13aa99'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13aaa3'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13aaa9'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13aaaa'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13aaab'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13aaac'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13aaaf'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13aab0'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13aabc'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13aabd'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13aabe'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13aac5'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13aac6'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13aac9'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13aaca'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13aad1'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13aad3'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13aadb'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13aadd'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13aadf'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13aae1'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13aae3'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13aaeb'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13aaef'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6aa99d5d899e13aaf0'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# ...
# {'_id': ObjectId('64f88f6ca99d5d899e143a93'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6ca99d5d899e143a96'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6ca99d5d899e143a97'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6ca99d5d899e143a98'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6ca99d5d899e143a99'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6ca99d5d899e143a9a'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6ca99d5d899e143a9c'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6ca99d5d899e143a9e'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6ca99d5d899e143aa1'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6ca99d5d899e143aa6'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6ca99d5d899e143aa8'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6ca99d5d899e143aa9'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6ca99d5d899e143aae'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6ca99d5d899e143ab7'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6ca99d5d899e143ab9'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6ca99d5d899e143aba'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6ca99d5d899e143abf'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6ca99d5d899e143ac0'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6ca99d5d899e143ac1'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6ca99d5d899e143ac2'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6ca99d5d899e143ac3'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6ca99d5d899e143ac8'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6ca99d5d899e143aca'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6ca99d5d899e143acb'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6ca99d5d899e143acd'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6ca99d5d899e143ace'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6ca99d5d899e143acf'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6ca99d5d899e143ad1'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6ca99d5d899e143ad2'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6ca99d5d899e143ad4'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6ca99d5d899e143ad5'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6ca99d5d899e143ad6'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6ca99d5d899e143add'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6ca99d5d899e143ae1'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6ca99d5d899e143ae3'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6ca99d5d899e143ae4'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6ca99d5d899e143ae5'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6ca99d5d899e143ae6'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6ca99d5d899e143ae7'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6ca99d5d899e143ae9'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6ca99d5d899e143aea'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6ca99d5d899e143af7'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6ca99d5d899e143af8'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6ca99d5d899e143afb'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6ca99d5d899e143aff'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6ca99d5d899e143b02'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6ca99d5d899e143b07'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6ca99d5d899e143b09'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6ca99d5d899e143b0f'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6ca99d5d899e143b10'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6ca99d5d899e143b12'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6ca99d5d899e143b1b'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6ca99d5d899e143b3e'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6ca99d5d899e143b45'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6ca99d5d899e143b4a'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6ca99d5d899e143b4e'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6ca99d5d899e143b50'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6ca99d5d899e143b51'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6ca99d5d899e143b54'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6ca99d5d899e143b56'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6ca99d5d899e143b58'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6ca99d5d899e143b59'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6ca99d5d899e143b5a'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6ca99d5d899e143b5b'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6ca99d5d899e143b5c'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6ca99d5d899e143b6c'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6ca99d5d899e143b70'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6ca99d5d899e143b7d'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6ca99d5d899e143b7f'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6ca99d5d899e143b84'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6ca99d5d899e143b85'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6ca99d5d899e143b91'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6ca99d5d899e143b92'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6ca99d5d899e143b98'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6ca99d5d899e143b9b'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6ca99d5d899e143b9e'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6ca99d5d899e143ba2'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6ca99d5d899e143ba4'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6ca99d5d899e143ba8'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6ca99d5d899e143baa'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6ca99d5d899e143bb8'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6ca99d5d899e143bc6'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6ca99d5d899e143bc7'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6ca99d5d899e143bcd'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6ca99d5d899e143bce'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6ca99d5d899e143bd4'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6ca99d5d899e143bda'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6ca99d5d899e143bdd'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6ca99d5d899e143be1'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6ca99d5d899e143be6'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6ca99d5d899e143be7'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6ca99d5d899e143beb'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6ca99d5d899e143bf7'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6ca99d5d899e143bf9'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6ca99d5d899e143bfa'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6ca99d5d899e143bfb'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6ca99d5d899e143bfc'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6ca99d5d899e143bff'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6ca99d5d899e143c01'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6ca99d5d899e143c04'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6ca99d5d899e143c05'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6ca99d5d899e143c06'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6ca99d5d899e143c08'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6ca99d5d899e143c0a'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6ca99d5d899e143c0b'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6ca99d5d899e143c0f'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6ca99d5d899e143c11'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6ca99d5d899e143c12'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6ca99d5d899e143c13'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6ca99d5d899e143c16'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6ca99d5d899e143c17'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6ca99d5d899e143c18'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6ca99d5d899e143c19'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6ca99d5d899e143c1a'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6ca99d5d899e143c1b'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6ca99d5d899e143c1e'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6ca99d5d899e143c22'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6ca99d5d899e143c27'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6ca99d5d899e143c29'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6ca99d5d899e143c2b'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6ca99d5d899e143c2c'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6ca99d5d899e143c30'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6ca99d5d899e143c35'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6ca99d5d899e143c36'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6ca99d5d899e143c37'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6ca99d5d899e143c3e'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6ca99d5d899e143c47'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6ca99d5d899e143c4c'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6ca99d5d899e143c4d'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6ca99d5d899e143c50'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6ca99d5d899e143c54'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6ca99d5d899e143c55'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6ca99d5d899e143c65'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6ca99d5d899e143c6e'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6ca99d5d899e143c6f'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6ca99d5d899e143c77'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6ca99d5d899e143c7f'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6ca99d5d899e143c87'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6ca99d5d899e143c8c'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6ca99d5d899e143c8e'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6ca99d5d899e143c92'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6ca99d5d899e143c97'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6ca99d5d899e143c9a'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f88f6ca99d5d899e143ca6'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('64f90c730d89e46200648faf'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}

# %% [markdown]
# 3. Update the new restaurant with the `BusinessTypeID` you found.

# %%
# Update the new restaurant with the correct BusinessTypeID
establishments.update_one({"BusinessName":"Penang Flavours"},
                          {'$set': {'BusinessTypeID':1}}
                         )

# %%
# Confirm that the new restaurant was updated
new_rest_updated = establishments.find_one({"BusinessName":"Penang Flavours"})
print(new_rest_updated)
# Out:
# {'_id': ObjectId('64f90c730d89e46200648faf'), 'BusinessName': 'Penang Flavours', 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1, 'AddressLine1': 'Penang Flavours', 'AddressLine2': '146A Plumstead Rd', 'AddressLine3': 'London', 'AddressLine4': '', 'PostCode': 'SE18 7DY', 'Phone': '', 'LocalAuthorityCode': '511', 'LocalAuthorityName': 'Greenwich', 'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk', 'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk', 'scores': {'Hygiene': '', 'Structural': '', 'ConfidenceInManagement': ''}, 'SchemeType': 'FHRS', 'geocode': {'longitude': '0.08384000', 'latitude': '51.49014200'}, 'RightToReply': '', 'Distance': 4623.972328074718, 'NewRatingPending': True}

# %% [markdown]
# 4. The magazine is not interested in any establishments in Dover, so check how many documents contain the Dover Local Authority. Then, remove any establishments within the Dover Local Authority from the database, and check the number of documents to ensure they were deleted.

# %%
# Find how many documents have LocalAuthorityName as "Dover"
query = {'LocalAuthorityName': 'Dover'}
documents_dover = establishments.count_documents(query)
documents_dover
# Out:
# 0

# %%
# Delete all documents where LocalAuthorityName is "Dover"
delete_dover = establishments.delete_many(query)
delete_dover

# %%
# Check if any remaining documents include Dover
remain_dover = establishments.count_documents(query)
remain_dover
# Out:
# 0

# %%
# Check that other documents remain with 'find_one'
documents_remain = establishments.find_one()
documents_remain
# Out:
# {'_id': ObjectId('64f88f6aa99d5d899e13a42f'),
#  'FHRSID': 289353,
#  'ChangesByServerID': 0,
#  'LocalAuthorityBusinessID': 'PI/000002468',
#  'BusinessName': 'St Marys COE (aided) Primary School',
#  'BusinessType': 'School/college/university',
#  'BusinessTypeID': 7845,
#  'AddressLine1': 'St Marys Church Of England Primary School',
#  'AddressLine2': 'Warren Road',
#  'AddressLine3': 'Folkestone',
#  'AddressLine4': 'Kent',
#  'PostCode': 'CT19 6QH',
#  'Phone': '',
#  'RatingValue': '5',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingDate': '2016-09-13T00:00:00',
#  'LocalAuthorityCode': '188',
#  'LocalAuthorityName': 'Folkestone and Hythe',
#  'LocalAuthorityWebSite': 'http://www.folkestone-hythe.gov.uk',
#  'LocalAuthorityEmailAddress': 'foodteam@folkestone-hythe.gov.uk',
#  'scores': {'Hygiene': 0, 'Structural': 0, 'ConfidenceInManagement': 0},
#  'SchemeType': 'FHRS',
#  'geocode': {'longitude': '1.194762', 'latitude': '51.085797'},
#  'RightToReply': '',
#  'Distance': 4591.871474174837,
#  'NewRatingPending': False,
#  'meta': {'dataSource': None,
#   'extractDate': '0001-01-01T00:00:00',
#   'itemCount': 0,
#   'returncode': None,
#   'totalCount': 0,
#   'totalPages': 0,
#   'pageSize': 0,
#   'pageNumber': 0},
#  'links': [{'rel': 'self',
#    'href': 'https://api.ratings.food.gov.uk/establishments/289353'}]}

# %% [markdown]
# 5. Some of the number values are stored as strings, when they should be stored as numbers.

# %% [markdown]
# Use `update_many` to convert `latitude` and `longitude` to decimal numbers.

# %%
# Change the data type from String to Decimal for longitude and latitude
establishments.update_many({}, [{'$set':{"geocode.longitude": {'$toDouble': '$geocode.longitude'}}} ])
establishments.update_many({}, [{'$set':{"geocode.latitude": {'$toDouble': '$geocode.latitude'}}} ])

# %% [markdown]
# Use `update_many` to convert `RatingValue` to integer numbers.

# %%
# Set non 1-5 Rating Values to Null
non_ratings = ["AwaitingInspection", "Awaiting Inspection", "AwaitingPublication", "Pass", "Exempt"]
establishments.update_many({"RatingValue": {"$in": non_ratings}}, [ {'$set':{ "RatingValue" : None}} ])

# %%
# Change the data type from String to Integer for RatingValue
establishments.update_many({}, [{'$set':{"RatingValue": {'$toInt': '$RatingValue'}}} ])

# %%
# Check that the coordinates and rating value are now numbers
establishments.find_one()
# Out:
# {'_id': ObjectId('64f88f6aa99d5d899e13a42f'),
#  'FHRSID': 289353,
#  'ChangesByServerID': 0,
#  'LocalAuthorityBusinessID': 'PI/000002468',
#  'BusinessName': 'St Marys COE (aided) Primary School',
#  'BusinessType': 'School/college/university',
#  'BusinessTypeID': 7845,
#  'AddressLine1': 'St Marys Church Of England Primary School',
#  'AddressLine2': 'Warren Road',
#  'AddressLine3': 'Folkestone',
#  'AddressLine4': 'Kent',
#  'PostCode': 'CT19 6QH',
#  'Phone': '',
#  'RatingValue': 5,
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingDate': '2016-09-13T00:00:00',
#  'LocalAuthorityCode': '188',
#  'LocalAuthorityName': 'Folkestone and Hythe',
#  'LocalAuthorityWebSite': 'http://www.folkestone-hythe.gov.uk',
#  'LocalAuthorityEmailAddress': 'foodteam@folkestone-hythe.gov.uk',
#  'scores': {'Hygiene': 0, 'Structural': 0, 'ConfidenceInManagement': 0},
#  'SchemeType': 'FHRS',
#  'geocode': {'longitude': 1.194762, 'latitude': 51.085797},
#  'RightToReply': '',
#  'Distance': 4591.871474174837,
#  'NewRatingPending': False,
#  'meta': {'dataSource': None,
#   'extractDate': '0001-01-01T00:00:00',
#   'itemCount': 0,
#   'returncode': None,
#   'totalCount': 0,
#   'totalPages': 0,
#   'pageSize': 0,
#   'pageNumber': 0},
#  'links': [{'rel': 'self',
#    'href': 'https://api.ratings.food.gov.uk/establishments/289353'}]}
